# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import sklearn
import scipy

# %%
df=pd.read_csv('dataset1')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (9551, 21)

# %%
df1=pd.read_csv('dataset2.csv')

# %%
df1.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df2=pd.merge(df,df1)

# %%
df2.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df2.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
df2.sample()
# Out:
#      Restaurant ID Restaurant Name  Country Code       City  \
# 917           2198         Welcome             1  Faridabad
#
#                         Address   Locality      Locality Verbose  Longitude  \
# 917  J140, Sector 10, Faridabad  Sector 10  Sector 10, Faridabad  77.328898
#
#       Latitude               Cuisines  ...  Has Table booking  \
# 917  28.377754  North Indian, Chinese  ...                Yes
#
#     Has Online delivery Is delivering now Switch to order menu Price range  \
# 917                  No                No                   No           2
#
#     Aggregate rating  Rating color  Rating text Votes Country
# 917              2.9        Orange      Average    13   India
#
# [1 rows x 22 columns]

# %%
df2.shape
# Out:
# (9551, 22)

# %%
df2.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df2.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
# df_zomato=df_zomato.drop(['Address','Locality Verbose','Country','Restaurant Name','Longitude','Latitude',],axis=1)
df2.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
## Checking if dataset contains any null

nan_values = df2.isna()
nan_columns = nan_values.any()

columns_with_nan = df2.columns[nan_columns].tolist()
print(columns_with_nan)
# Out:
# ['Cuisines']

# %% [markdown]
# Cuisines seem to contain null values. Hence any further analysis involving Cuisines the NaN values has to be considered.
#
# There is another file that is also available along with this dataset

# %%
#Understanding the Rating aggregate, color, and text
df3=df2.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating count'})
df3
# Out:
#     Aggregate rating Rating color Rating text  Rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [raw]
# The above information help us to understand the relation between Aggregate rating, color, and text.
#
# Rating 0 — White — Not rated
# Rating 1.8 to 2.4 — Red — Poor
# Rating 2.5 to 3.4 — Orange — Average
# Rating 3.5 to 3.9 — Yellow — Good
# Rating 4.0 to 4.4 — Green — Very Good
# Rating 4.5 to 4.9 — Dark Green — Excellent

# %%
plt.figure(figsize=(12,6))
plt.title('Rating color')
sns.barplot(x=df3['Rating color'],y=df3['Rating count'])
plt.show()

# %% [markdown]
# maximum restaurants seems to have gone No ratings.

# %%
No_rating = df2[df2['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:'Rating count'})
No_rating
# Out:
#           Country  Rating count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %% [markdown]
# India seems to have maximum unrated restaurants. In India the culture of ordering online food is still gaining momentum hence most of the restaurants are still unrated on Zomato as people might be preferring to visiting the restaurant for a meal.

# %%
country_currency = df2[['Country','Currency']].groupby(['Country','Currency']).size().reset_index(name='count').drop('count', axis=1, inplace=False)
country_currency.sort_values('Currency').reset_index(drop=True)
# Out:
#            Country                Currency
# 0      Phillipines        Botswana Pula(P)
# 1           Brazil      Brazilian Real(R$)
# 2        Australia               Dollar($)
# 3           Canada               Dollar($)
# 4        Singapore               Dollar($)
# 5    United States               Dollar($)
# 6              UAE      Emirati Diram(AED)
# 7            India      Indian Rupees(Rs.)
# 8        Indonesia  Indonesian Rupiah(IDR)
# 9      New Zealand           NewZealand($)
# 10  United Kingdom              Pounds(��)
# 11           Qatar         Qatari Rial(QR)
# 12    South Africa                 Rand(R)
# 13       Sri Lanka   Sri Lankan Rupee(LKR)
# 14          Turkey        Turkish Lira(TL)

# %%
plt.figure(figsize=(12,6))
plt.title('Online Delivery Distribution')
plt.pie(df2['Has Online delivery'].value_counts()/9551*100, labels=df2['Has Online delivery'].value_counts().index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# only 25% has online delivedry rest of people go restarurants and order

# %%
#check locality wise maximum hotels are listed in zomato 
Delhi = df2[(df2.City == 'New Delhi')]
plt.figure(figsize=(12,6))
sns.barplot(x=Delhi.Locality.value_counts().head(10), y=Delhi.Locality.value_counts().head(10).index)

plt.ylabel(None);
plt.xlabel('Number of Resturants')
plt.title('Resturants Listing on Zomato');

# %% [markdown]
# connaught place seems to have a high no of restaurants registered with zomato.

# %%
# I achieve this by the following steps

## Fetching the resturants having 'Excellent' and 'Very Good' rating
ConnaughtPlace = Delhi[(Delhi.Locality.isin(['Connaught Place'])) & (Delhi['Rating text'].isin(['Excellent','Very Good']))]

ConnaughtPlace = ConnaughtPlace.Cuisines.value_counts().reset_index()

## Extracing all the cuisens in a single list
cuisien = []
for x in ConnaughtPlace['index']: 
    cuisien.append(x)

# cuisien = '[%s]'%', '.join(map(str, cuisien))
cuisien
# Out:
# ['North Indian, Chinese, Italian, Continental',
#  'Continental, Italian, Asian, Indian',
#  'Continental, Mediterranean, Italian, North Indian',
#  'Bakery, Desserts, Fast Food',
#  'North Indian, Continental',
#  'North Indian, European, Asian, Mediterranean',
#  'Continental, North Indian, Italian, Asian',
#  'North Indian, Afghani, Mughlai',
#  'North Indian, European',
#  'Cafe',
#  'Continental, Mexican, Burger, American, Pizza, Tex-Mex',
#  'South Indian',
#  'Asian, North Indian',
#  'Italian, Mexican, Continental, North Indian, Finger Food',
#  'Continental, American, Asian, North Indian',
#  'Fast Food, American, Burger',
#  'North Indian, Mediterranean, Asian, Fast Food',
#  'Ice Cream',
#  'Healthy Food, Continental, Italian',
#  'Japanese',
#  'Modern Indian',
#  'Chinese',
#  'Continental, North Indian, Chinese, Mediterranean',
#  'North Indian, Chinese, Italian, American, Middle Eastern',
#  'Biryani, Hyderabadi',
#  'Biryani, North Indian, Hyderabadi',
# ...

# %%
top_locality = Delhi.Locality.value_counts().head(10)
sns.set_theme(style="darkgrid")
plt.figure(figsize=(12,6))
ax = sns.countplot(y= "Locality", hue="Has Online delivery", data=Delhi[Delhi.Locality.isin(top_locality.index)])
plt.title('Resturants Online Delivery');

# %% [markdown]
# restaurants in other localities accept online delivery, apart shahdara
#
# online delivery seems higher on malviya nagar and defence colony

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="Average Cost for two", y="Aggregate rating", hue='Price range', data=Delhi)

plt.xlabel("Average Cost for two")
plt.ylabel("Aggregate rating")
plt.title('Rating vs Cost of Two');

# %%
Delhi['Rating text'].value_counts()
# Out:
# Average      2495
# Not rated    1425
# Good         1128
# Very Good     300
# Poor           97
# Excellent      28
# Name: Rating text, dtype: int64

# %%
#Removing useless columns from the data
useless_columns=['Restaurant ID','Restaurant Name','City','Address','Locality','Locality Verbose','Cuisines']
df2=df2.drop(useless_columns,axis=1)
df2.head()
# Out:
#    Country Code   Longitude   Latitude  Average Cost for two  \
# 0           162  121.027535  14.565443                  1100
# 1           162  121.014101  14.553708                  1200
# 2           162  121.056831  14.581404                  4000
# 3           162  121.056475  14.585318                  1500
# 4           162  121.057508  14.584450                  1500
#
#            Currency Has Table booking Has Online delivery Is delivering now  \
# 0  Botswana Pula(P)               Yes                  No                No
# 1  Botswana Pula(P)               Yes                  No                No
# 2  Botswana Pula(P)               Yes                  No                No
# 3  Botswana Pula(P)                No                  No                No
# 4  Botswana Pula(P)               Yes                  No                No
#
#   Switch to order menu  Price range  Aggregate rating Rating color  \
# 0                   No            3               4.8   Dark Green
# ...

# %%
# Visual Exploratory Data Analysis
# Categorical Variables: barplot
# # continuous variables: histogram

# %%
def plotbarcharts (inpData, colstoplot):
    
    fig, subplot=plt.subplots(nrows=1,ncols=len(colstoplot), figsize=(20,5))
    fig.suptitle('Bar charts of: '+str(colstoplot))
    
    for colName, plotNumber in zip(colstoplot, range(len(colstoplot))):
        inpData.groupby(colName).size().plot(kind='bar', ax=subplot[plotNumber])

# %%
plotbarcharts(inpData=df2,colstoplot=['Country Code','Currency','Has Table booking','Has Online delivery','Is delivering now','Switch to order menu','Price range'])

# %%
df2.hist(['Longitude','Latitude','Votes','Average Cost for two'], figsize = (18,10))
plt.show()

# %%
#find the nearest values to 400 mark

df2['Votes'][df2['Votes']<4000].sort_values(ascending=False)
# Out:
# 7863    3986
# 821     3848
# 3992    3697
# 3119    3591
# 1861    3569
#         ...
# 7809       0
# 8560       0
# 8558       0
# 7810       0
# 4784       0
# Name: Votes, Length: 9532, dtype: int64

# %%
#replacing outliers with nearest possible value
df2['Votes'][df2['Votes']>4000] = 3986

# %%
#replacing outlers for average cost for two
#finding nearest values to 50000 mark
df2['Average Cost for two'][df2['Average Cost for two']<50000].sort_values(ascending=False)
# Out:
# 7543    8000
# 4088    7000
# 4087    6500
# 7494    6000
# 7538    6000
#         ...
# 85         0
# 87         0
# 328        0
# 374        0
# 9242       0
# Name: Average Cost for two, Length: 9530, dtype: int64

# %%
#Replacing outliers with nearest possible value
df2['Average Cost for two'][df2['Average Cost for two']>50000]=8000

# %%
# Visualizing distribution after outlier treatment
df2.hist(['Votes','Average Cost for two'], figsize=(18,5))
plt.show()

# %%
#finding how many missing values are there for each column
df2.isnull().sum()
# Out:
# Country Code            0
# Longitude               0
# Latitude                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# No missing values in this data!!

# %%
df2.columns
# Out:
# Index(['Country Code', 'Longitude', 'Latitude', 'Average Cost for two',
#        'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes', 'Country'],
#       dtype='object')

# %%
ContiCols=['Longitude','Latitude','Votes','Average Cost for two']

#plotting scatter chart for each predictor vs the target variable
for predictor in ContiCols:
    
    df2.plot.scatter(x=predictor,y= 'Aggregate rating',figsize=(10,5), title=predictor +'Vs Rating')
    plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
#calculating correlation matrix
contiCols=['Aggregate rating','Longitude','Latitude','Votes','Average Cost for two']

#creating the correlation matrix
Corr_df2=df2[contiCols].corr()

# %%
Corr_df2
# Out:
#                       Aggregate rating  Longitude  Latitude     Votes  \
# Aggregate rating              1.000000  -0.116818  0.000516  0.346906
# Longitude                    -0.116818   1.000000  0.043207 -0.101381
# Latitude                      0.000516   0.043207  1.000000 -0.019687
# Votes                         0.346906  -0.101381 -0.019687  1.000000
# Average Cost for two          0.240494   0.210272 -0.064748  0.245662
#
#                       Average Cost for two
# Aggregate rating                  0.240494
# Longitude                         0.210272
# Latitude                         -0.064748
# Votes                             0.245662
# Average Cost for two              1.000000

# %%
#Filtering only those columns wher absolute correlation > 0.5 with Target varibale 
# reduce the 0.5 threshold if no variable is selected like in this case

Corr_df2['Aggregate rating'][abs(Corr_df2['Aggregate rating']) > 0.2]
# Out:
# Aggregate rating        1.000000
# Votes                   0.346906
# Average Cost for two    0.240494
# Name: Aggregate rating, dtype: float64

# %%
# catcolslist=['Has Table booking','Has Table booking','Price range']

sns.boxplot(x='Has Table booking',y='Aggregate rating',data=df2)
plt.show()

# %%
sns.boxplot(x='Has Online delivery',y='Aggregate rating',data=df2)
plt.show()

# %%
sns.boxplot(x='Price range',y='Aggregate rating',data=df2)
plt.show()

# %%
def FunctionAnova(inpData,TargetVariable, Catpredlist):
    from scipy.stats import f_oneway
    
    #creating an empty list of final selected predictors
    
    SelectedPredictors=[]
    
    for predictor in Catpredlist:
        categoryGroupLists =inpData.groupby(predictor)[TargetVariable].apply(list)
        AnovaResults = f_oneway(*categoryGroupLists)
        
        if (AnovaResults[1]<0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor,'is NOT correlated with,', TargetVariable, '| P-value', AnovaResults[1])
            
    return(SelectedPredictors)

# %%
Catpredlist = ['Has Table booking','Has Online delivery','Price range']
# inpData=df2
FunctionAnova( inpData=df2,
              TargetVariable='Aggregate rating',
              Catpredlist = Catpredlist)
# Out:
# Has Table booking is correlated with Aggregate rating | P-Value: 2.4808519133558066e-78
# Has Online delivery is correlated with Aggregate rating | P-Value: 1.4004463504064177e-110
# Price range is correlated with Aggregate rating | P-Value: 0.0
# ['Has Table booking', 'Has Online delivery', 'Price range']

# %%
SelectedColumns=['Votes','Average Cost for two','Has Table booking','Has Online delivery','Price range']

Dataforml=df2[SelectedColumns]
Dataforml.head()
# Out:
#    Votes  Average Cost for two Has Table booking Has Online delivery  \
# 0    314                  1100               Yes                  No
# 1    591                  1200               Yes                  No
# 2    270                  4000               Yes                  No
# 3    365                  1500                No                  No
# 4    229                  1500               Yes                  No
#
#    Price range
# 0            3
# 1            3
# 2            4
# 3            4
# 4            4

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
Dataforml['Has Table booking'] = le.fit_transform(df['Has Table booking'])
Dataforml['Has Online delivery'] = le.fit_transform(df['Has Online delivery'])

# %%
#convert float target in int

# %%
df2['Aggregate rating'] = df2['Aggregate rating'].astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Longitude             9551 non-null   float64
#  2   Latitude              9551 non-null   float64
#  3   Average Cost for two  9551 non-null   int64
#  4   Currency              9551 non-null   object
#  5   Has Table booking     9551 non-null   object
#  6   Has Online delivery   9551 non-null   object
#  7   Is delivering now     9551 non-null   object
#  8   Switch to order menu  9551 non-null   object
#  9   Price range           9551 non-null   int64
#  10  Aggregate rating      9551 non-null   int32
#  11  Rating color          9551 non-null   object
#  12  Rating text           9551 non-null   object
#  13  Votes                 9551 non-null   int64
#  14  Country               9551 non-null   object
# ...

# %%
#adding variable to the data
Dataforml['Aggregate rating']=df2['Aggregate rating']
#printing sample rows
Dataforml.head()
# Out:
#    Votes  Average Cost for two  Has Table booking  Has Online delivery  \
# 0    314                  1100                  1                    0
# 1    591                  1200                  1                    0
# 2    270                  4000                  1                    0
# 3    365                  1500                  0                    0
# 4    229                  1500                  1                    0
#
#    Price range  Aggregate rating
# 0            3                 4
# 1            3                 4
# 2            4                 4
# 3            4                 4
# 4            4                 4

# %%
Dataforml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Votes                 9551 non-null   int64
#  1   Average Cost for two  9551 non-null   int64
#  2   Has Table booking     9551 non-null   int32
#  3   Has Online delivery   9551 non-null   int32
#  4   Price range           9551 non-null   int64
#  5   Aggregate rating      9551 non-null   int32
# dtypes: int32(3), int64(3)
# memory usage: 410.4 KB

# %%
Dataforml['Has Online delivery'].value_counts()
# Out:
# 0    7100
# 1    2451
# Name: Has Online delivery, dtype: int64

# %%
Dataforml['Has Table booking'].value_counts()
# Out:
# 0    8393
# 1    1158
# Name: Has Table booking, dtype: int64

# %%
Dataforml['Aggregate rating'].value_counts()
# Out:
# 3    4590
# 0    2148
# 2    1430
# 4    1380
# 1       3
# Name: Aggregate rating, dtype: int64

# %%
Dataforml.columns
# Out:
# Index(['Votes', 'Average Cost for two', 'Has Table booking',
#        'Has Online delivery', 'Price range', 'Aggregate rating'],
#       dtype='object')

# %% [markdown]
# # In this model predict the Average cost for two

# %%
#separate Target variable and predictor variables

TargetVariable='Average Cost for two'
Predictors=['Votes','Aggregate rating','Has Table booking','Has Online delivery','Price range']

x=Dataforml[Predictors].values
y=Dataforml[TargetVariable].values

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=15)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lrfit=lr.fit(x_train,y_train)
pred=lr.predict(x_test)

from sklearn import metrics
print('R2 Value:',metrics.r2_score(y_train,lrfit.predict(x_train)))
# Out:
# R2 Value: 0.4493001641110217

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
RF_Model=RandomForestRegressor(n_estimators=650,random_state=650,min_samples_leaf=.0001)
RF_Model.fit(x_train,y_train)
y_predict=RF_Model.predict(x_test)
r2_score(y_test,y_predict)
# Out:
# 0.3210188905799095

# %%
#Preparing Extra Tree Regression
from sklearn.ensemble import  ExtraTreesRegressor
ET_Model=ExtraTreesRegressor(n_estimators = 120)
ET_Model.fit(x_train,y_train)
y_predict=ET_Model.predict(x_test)


from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.2113016614913713

# %% [markdown]
# Linear Regression gives us the best model

# %%
#use pickle to save our model so that we can use it later
import pickle
pickle.dump(lr,open('model.pkl','wb'))
model=pickle.load(open('model.pkl','rb'))

# %% [markdown]
# # In this model predict the Price range

# %%
#separate Target variable and predictor variables

TargetVariable='Price range'
Predictors=['Votes','Aggregate rating','Has Table booking','Has Online delivery','Average Cost for two']

x=Dataforml[Predictors].values
y=Dataforml[TargetVariable].values

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=15)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lrfit=lr.fit(x_train,y_train)
pred=lr.predict(x_test)

from sklearn import metrics
print('R2 Value:',metrics.r2_score(y_train,lrfit.predict(x_train)))
# Out:
# R2 Value: 0.5197927089360862

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
RF_Model=RandomForestRegressor(n_estimators=650,random_state=245,min_samples_leaf=.0001)
RF_Model.fit(x_train,y_train)
y_predict=RF_Model.predict(x_test)
r2_score(y_test,y_predict)
# Out:
# 0.861906408754655

# %%
from sklearn.ensemble import  ExtraTreesRegressor
ET_Model=ExtraTreesRegressor(n_estimators = 120)
ET_Model.fit(x_train,y_train)
y_predict=ET_Model.predict(x_test)


from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.8564956618877622

# %% [markdown]
# Extra Tree Regression gives us the best model

# %%
pickle.dump(ET_Model,open('model.pkl','wb'))
model=pickle.load(open('model.pkl','rb'))
